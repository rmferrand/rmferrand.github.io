# %% [raw]
# ---
# title: "Work Experience - Robbie Ferrand"
# format:
#   html:
#     include-before-body: ../_includes/card.html
# ---

# %% [markdown]
# ::: {#page-content}
# <h1>Work Experience</h1>
#
# <!-- Wrapper for first section -->
#
# ::: {style="margin-bottom: 50px;"}
# ::: {style="display: flex; align-items: center; gap: 20px;"}
# <img src="../images/ncsu.jpg" alt="ncsu" style="width: 200px; height: auto;"/>
#
# <div>
#
# <p style="margin: 0;">
#
# North Carolina State University
#
# </p>
#
# <p style="margin: 0;">
#
# August 2023 - December 2024
#
# </p>
#
# <p style="margin: 0;">
#
# Graduate Student Instructor
#
# </p>
#
# <button class="read-more-toggle" data-target="#ncsu-roles">
#
# Roles and Responsibilities
#
# </button>
#
# ::: {#ncsu-roles .roles-content}
# <ul>
#
# <li>Grade papers and provide feedback to students.</li>
#
# <li>Conduct weekly tutorial sessions.</li>
#
# <li>Develop instructional materials and presentations.</li>
#
# <li>Assist in organizing events and workshops.</li>
#
# </ul>
# :::
#
# </div>
# :::
# :::
#
# <!-- Wrapper for second section -->
#
# <div>
#
# ::: {style="display: flex; align-items: center; gap: 20px;"}
# <img src="../images/dhs.png" alt="dhs" style="width: 200px; height: auto;"/>
#
# <div>
#
# <p style="margin: 0;">
#
# U.S Department Of Homeland Security
#
# </p>
#
# <p style="margin: 0;">
#
# January 2022 - July 2023
#
# </p>
#
# <p style="margin: 0;margin-bottom: 10px;">
#
# Data Scientist II
#
# </p>
#
# <p style="margin: 0;">
#
# January 2020 - December 2021
#
# </p>
#
# <p style="margin: 0;">
#
# Data Scientist I
#
# </p>
#
# <button class="read-more-toggle" data-target="#dhs-roles">
#
# Roles and Responsibilities
#
# </button>
#
# ::: {#dhs-roles .roles-content}
# <ul>
#
# <li>Developed machine learning models for predictive analytics.</li>
#
# <li>Processed and analyzed large datasets using Python and SQL.</li>
#
# <li>Collaborated with cross-functional teams to implement data-driven solutions.</li>
#
# <li>Created data visualizations for senior management reports.</li>
#
# </ul>
# :::
#
# </div>
# :::
#
# </div>
# :::
#
#
# ```{js}
# // Add event listeners to all 'Roles and Responsibilities' buttons
# document.querySelectorAll('.read-more-toggle').forEach(button => {
#   button.addEventListener('click', function() {
#     const targetId = this.getAttribute('data-target');
#     const targetElement = document.querySelector(targetId);
#
#     // Toggle the active class on the button
#     this.classList.toggle('active');
#
#     // Toggle visibility of the corresponding roles content
#     if (targetElement.style.display === "none" || targetElement.style.display === "") {
#       targetElement.style.display = "block";
#     } else {
#       targetElement.style.display = "none";
#     }
#   });
# });
# ```
